# %% [markdown]
# ## Goal
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %%
import numpy as np

#Generate 2000 random lattitudes and longitudes
latitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
coordinates = list(zip(latitudes,longitudes))

# %%
from config import weather_api_key
from citipy import citipy

#Create base url string
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#generate a list of cities based off coordinate list
cityList = []
for coordinate in coordinates:
    cityList.append(citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
cityList


#api calls to create cities 
#for i in len(coordinates):
# Out:
# ['dinsor',
#  'dikson',
#  'talnakh',
#  'the valley',
#  'biskamzha',
#  'cape town',
#  'tyukhtet',
#  'pedasi',
#  'beira',
#  'qaanaaq',
#  'nanortalik',
#  'belushya guba',
#  'east london',
#  'qaanaaq',
#  'bengkulu',
#  'tasiilaq',
#  'cape town',
#  'port alfred',
#  'port elizabeth',
#  'bredasdorp',
#  'ponta do sol',
#  'grindavik',
#  'barentsburg',
#  'ribeira grande',
#  'jamestown',
#  'guanare',
#  'touros',
#  'ribeira grande',
#  'illoqqortoormiut',
#  'tarudant',
#  'tasiilaq',
#  'busselton',
#  'itarema',
#  'punta arenas',
#  'kondopoga',
#  'gouyave',
#  'karauzyak',
#  'karatau',
#  'luderitz',
#  'laguna',
#  'hermanus',
#  'ayagoz',
#  'handwara',
#  'busselton',
#  'amapa',
#  'illoqqortoormiut',
#  'port alfred',
#  'jamestown',
#  'cockburn town',
#  'punta arenas',
#  'tougue',
#  'busselton',
#  'taolanaro',
#  'port alfred',
#  'ilulissat',
#  'salalah',
#  'bredasdorp',
#  'ushuaia',
#  'jamestown',
#  'ushuaia',
#  'hithadhoo',
#  'nanortalik',
#  'belushya guba',
#  'mar del plata',
#  'busselton',
#  'luderitz',
#  'hithadhoo',
#  'ribeira grande',
#  'kjollefjord',
#  'kostomuksha',
#  'port elizabeth',
#  'somerset',
#  'cockburn town',
#  'sikandra',
#  'bauchi',
#  'cururupu',
#  'hofn',
#  'tocopilla',
#  'taolanaro',
#  'roald',
#  'tsihombe',
#  'margate',
#  'sao filipe',
#  'sioux lookout',
#  'jamestown',
#  'tefe',
#  'cockburn town',
#  'pujehun',
#  'ilulissat',
#  'beloha',
#  'dudinka',
#  'codrington',
#  'cape town',
#  'praia',
#  'hofn',
#  'ushuaia',
#  'kitgum',
#  'tasiilaq',
#  'amderma',
#  'ushuaia',
#  'richards bay',
#  'barentsburg',
#  'am timan',
#  'mysliborz',
#  'attawapiskat',
#  'ropczyce',
#  'arlit',
#  'bredasdorp',
#  'polgardi',
#  'taolanaro',
#  'tasiilaq',
#  'hithadhoo',
#  'road town',
#  'mosquera',
#  'correntina',
#  'tsihombe',
#  'ushuaia',
#  'bonthe',
#  'ushuaia',
#  'bonfim',
#  'montoro',
#  'verwoerdburg',
#  'dwarka',
#  'san-pedro',
#  'longyearbyen',
#  'plettenberg bay',
#  'tasiilaq',
#  'lekoni',
#  'qaanaaq',
#  'ushuaia',
#  'tessalit',
#  'port elizabeth',
#  'bredasdorp',
#  'qaanaaq',
#  'kourou',
#  'ushuaia',
#  'hermanus',
#  'manama',
#  'narsaq',
#  'mar del plata',
#  'nantucket',
#  'ushuaia',
#  'kruisfontein',
#  'longlac',
#  'arica',
#  'mangrol',
#  'georgetown',
#  'taolanaro',
#  'hermanus',
#  'tumannyy',
#  'rocha',
#  'punta arenas',
#  'ondangwa',
#  'hermanus',
#  'jamestown',
#  'mar del plata',
#  'campoverde',
#  'cape town',
#  'ushuaia',
#  'antofagasta',
#  'richards bay',
#  'port saint lucie',
#  'arraial do cabo',
#  'arlit',
#  'illela',
#  'busselton',
#  'ushuaia',
#  'fraga',
#  'port alfred',
#  'la asuncion',
#  'mrirt',
#  'itarema',
#  'karasjok',
#  'tabarqah',
#  'modasa',
#  'viedma',
#  'jumla',
#  'senhor do bonfim',
#  'saldanha',
#  'ribeira grande',
#  'orangeburg',
#  'yar-sale',
#  'lagoa',
#  'lagoa',
#  'emba',
#  'nushki',
#  'mar del plata',
#  'saint-philippe',
#  'ust-kan',
#  'othonoi',
#  'kristiinankaupunki',
#  'ushuaia',
#  'dikson',
#  'georgetown',
#  'rawson',
#  'husavik',
#  'uribia',
#  'clarksburg',
#  'casma',
#  'vila velha',
#  'mogadishu',
#  'mahebourg',
#  'saint george',
#  'minab',
#  'terrace bay',
#  'qaanaaq',
#  'taywarah',
#  'rawson',
#  'saint george',
#  'malacacheta',
#  'ushuaia',
#  'clyde river',
#  'himatnagar',
#  'amapa',
#  'longyearbyen',
#  'grand gaube',
#  'hermanus',
#  'warqla',
#  'barentsburg',
#  'muli',
#  'margate',
#  'bocas del toro',
#  'saint george',
#  'camargo',
#  'nioro',
#  'taolanaro',
#  'taolanaro',
#  'tasiilaq',
#  'adrar',
#  'barentsburg',
#  'ginda',
#  'chuy',
#  'nokha',
#  'kilindoni',
#  'kidal',
#  'bardiyah',
#  'jamestown',
#  'goure',
#  'east london',
#  'punta arenas',
#  'grand river south east',
#  'hambantota',
#  'grand river south east',
#  'victoria',
#  'warqla',
#  'mar del plata',
#  'sao joao da barra',
#  'saveh',
#  'vila franca do campo',
#  'naryan-mar',
#  'san cristobal',
#  'bambous virieux',
#  'amderma',
#  'boa vista',
#  'bonavista',
#  'valdivia',
#  'saldanha',
#  'carnarvon',
#  'mar del plata',
#  'jamestown',
#  'arraial do cabo',
#  'rock sound',
#  'ozgon',
#  'amderma',
#  'ciudad bolivar',
#  'attawapiskat',
#  'cidreira',
#  'cabedelo',
#  'bonavista',
#  'bambous virieux',
#  'pisco',
#  'yokadouma',
#  'thinadhoo',
#  'sao filipe',
#  'naberera',
#  'saint-philippe',
#  'coquimbo',
#  'yar-sale',
#  'volzhsk',
#  'urdzhar',
#  'arraial do cabo',
#  'illoqqortoormiut',
#  'georgetown',
#  'illoqqortoormiut',
#  'korla',
#  'iracoubo',
#  'hermanus',
#  'swansea',
#  'camabatela',
#  'soyo',
#  'lebu',
#  'mahebourg',
#  'sisimiut',
#  'jizan',
#  'klaksvik',
#  'ushuaia',
#  'walvis bay',
#  'bay city',
#  'kardamaina',
#  'los llanos de aridane',
#  'dikson',
#  'ribeira grande',
#  'ushuaia',
#  'rio blanco',
#  'cape town',
#  'grand gaube',
#  'qaanaaq',
#  'uwayl',
#  'ramnagar',
#  'saint george',
#  'impfondo',
#  'hermanus',
#  'prudnik',
#  'karkaralinsk',
#  'jamestown',
#  'tsihombe',
#  'port alfred',
#  'coquimbo',
#  'belushya guba',
#  'dingle',
#  'chuy',
#  'bengkulu',
#  'longyearbyen',
#  'ushuaia',
#  'saint-pierre',
#  'belushya guba',
#  'qaqortoq',
#  'ushuaia',
#  'mar del plata',
#  'djambala',
#  'tasiilaq',
#  'skalistyy',
#  'avanigadda',
#  'minsk',
#  'punta arenas',
#  'dudinka',
#  'cape town',
#  'torbay',
#  'santiago',
#  'georgetown',
#  'pokhara',
#  'longyearbyen',
#  'port-gentil',
#  'ushuaia',
#  'newberry',
#  'belen',
#  'amderma',
#  'vardo',
#  'barra patuca',
#  'hermanus',
#  'amderma',
#  'sao jose da coroa grande',
#  'georgetown',
#  'ushuaia',
#  'faya',
#  'port elizabeth',
#  'caravelas',
#  'georgetown',
#  'punta arenas',
#  'taolanaro',
#  'kruisfontein',
#  'saint-pierre',
#  'zaltan',
#  'port alfred',
#  'ushuaia',
#  'ilo',
#  'hermanus',
#  'hermanus',
#  'rocha',
#  'jamestown',
#  'mao',
#  'kovdor',
#  'irondequoit',
#  'berlevag',
#  'georgetown',
#  'illoqqortoormiut',
#  'port alfred',
#  'dwarka',
#  'nouadhibou',
#  'pangnirtung',
#  'zhetybay',
#  'hithadhoo',
#  'oriximina',
#  'hithadhoo',
#  'georgetown',
#  'patrocinio',
#  'victoria',
#  'ilulissat',
#  'sao filipe',
#  'vestmannaeyjar',
#  'surt',
#  'mercedes',
#  'cape town',
#  'coihaique',
#  'sassandra',
#  'carnarvon',
#  'ponta do sol',
#  'illoqqortoormiut',
#  'punta arenas',
#  'hermanus',
#  'aflu',
#  'taolanaro',
#  'san cristobal',
#  'chaman',
#  'iqaluit',
#  'ushuaia',
#  'pisco',
#  'pisco',
#  'dzhusaly',
#  'lasa',
#  'busselton',
#  'longyearbyen',
#  'cidreira',
#  'khash',
#  'bredasdorp',
#  'ponta do sol',
#  'punta arenas',
#  'san cristobal',
#  'ushuaia',
#  'quibor',
#  'luderitz',
#  'marcona',
#  'taolanaro',
#  'luderitz',
#  'martyush',
#  'ushuaia',
#  'ilulissat',
#  'klaksvik',
#  'illoqqortoormiut',
#  'boo',
#  'leshukonskoye',
#  'busselton',
#  'hithadhoo',
#  'ponta do sol',
#  'tiszanana',
#  'west bay',
#  'paamiut',
#  'busselton',
#  'moshny',
#  'bredasdorp',
#  'upernavik',
#  'darnah',
#  'cape town',
#  'lagoa',
#  'sayyan',
#  'busselton',
#  'boralday',
#  'east london',
#  'paveh',
#  'punta arenas',
#  'maceio',
#  'ostrovnoy',
#  'skibbereen',
#  'cape town',
#  'bhanjanagar',
#  'taolanaro',
#  'punta arenas',
#  'zeliezovce',
#  'ustka',
#  'saint george',
#  'phalaborwa',
#  'ribeira grande',
#  'walvis bay',
#  'hambantota',
#  'casablanca',
#  'andenes',
#  'opuwo',
#  'necochea',
#  'busselton',
#  'kralendijk',
#  'fenton',
#  'sao filipe',
#  'busselton',
#  'naryan-mar',
#  'saint george',
#  'gualeguaychu',
#  'dikson',
#  'saint george',
#  'touros',
#  'cockburn harbour',
#  'faya',
#  'cape town',
#  'odweyne',
#  'azad shahr',
#  'cape town',
#  'sabla',
#  'east london',
#  'nakambala',
#  'sistranda',
#  'tabory',
#  'skelleftea',
#  'attawapiskat',
#  'east london',
#  'mpwapwa',
#  'kirkwall',
#  'cape town',
#  'buta',
#  'trincomalee',
#  'coquimbo',
#  'upernavik',
#  'torbay',
#  'sucua',
#  'attawapiskat',
#  'saint-philippe',
#  'vilhena',
#  'middletown',
#  'mitu',
#  'alexandria',
#  'port alfred',
#  'bredasdorp',
#  'angoche',
#  'husavik',
#  'belushya guba',
#  'awbari',
#  'port alfred',
#  'gamba',
#  'arraial do cabo',
#  'ouadda',
#  'ostrovnoy',
#  'tsihombe',
#  'ushuaia',
#  'pokhara',
#  'qaanaaq',
#  'port alfred',
#  'belmonte',
#  'hvide sande',
#  'luderitz',
#  'pitea',
#  'ushuaia',
#  'busselton',
#  'necochea',
#  'challans',
#  'jiddah',
#  'hermanus',
#  'san ramon',
#  'praia da vitoria',
#  'tasiilaq',
#  'dikson',
#  'sao miguel do araguaia',
#  'rochdale',
#  'rawson',
#  'jamestown',
#  'meulaboh',
#  'lebu',
#  'victoria',
#  'belushya guba',
#  'hithadhoo',
#  'nisia floresta',
#  'cayenne',
#  'trincomalee',
#  'ushuaia',
#  'ushuaia',
#  'salalah',
#  'bredasdorp',
#  'malakal',
#  'moengo',
#  'bredasdorp',
#  'saint-philippe',
#  'santa cruz',
#  'chanderi',
#  'rocha',
#  'ushuaia',
#  'hamilton',
#  'hithadhoo',
#  'peniche',
#  'sambava',
#  'port elizabeth',
#  'salalah',
#  'cidreira',
#  'requena',
#  'east london',
#  'punta arenas',
#  'busselton',
#  'barentsburg',
#  'nanortalik',
#  'cangucu',
#  'bredasdorp',
#  'port alfred',
#  'calafell',
#  'koksovyy',
#  'crystal beach',
#  'mar del plata',
#  'jamestown',
#  'asfi',
#  'phalombe',
#  'shalakusha',
#  'ginda',
#  'barra do garcas',
#  'castro',
#  'dikson',
#  'amderma',
#  'attawapiskat',
#  'malangali',
#  'kuche',
#  'mahebourg',
#  'murgab',
#  'sorvag',
#  'ushuaia',
#  'busselton',
#  'cape town',
#  'charagua',
#  'mao',
#  'port blair',
#  'kachiry',
#  'gat',
#  'chiredzi',
#  'port-cartier',
#  'punta arenas',
#  'mahibadhoo',
#  'pisco',
#  'tasiilaq',
#  'amderma',
#  'dikson',
#  'key west',
#  'bur gabo',
#  'qaanaaq',
#  'ushuaia',
#  'ushuaia',
#  'georgetown',
#  'bud',
#  'himora',
#  'leua',
#  'hermanus',
#  'georgetown',
#  'mar del plata',
#  'torbay',
#  'sistranda',
#  'grand gaube',
#  'balezino',
#  'nata',
#  'ushuaia',
#  'ushuaia',
#  'busselton',
#  'humaita',
#  'gonzalez',
#  'mar del plata',
#  'adre',
#  'punta arenas',
#  'barra patuca',
#  'tasiilaq',
#  'bredasdorp',
#  'ushuaia',
#  'bredasdorp',
#  'east london',
#  'nyuksenitsa',
#  'paoua',
#  'georgetown',
#  'mahebourg',
#  'louisbourg',
#  'tsihombe',
#  'busselton',
#  'port elizabeth',
#  'saint-philippe',
#  'saint george',
#  'victoria',
#  'barra do garcas',
#  'clyde river',
#  'georgetown',
#  'saldanha',
#  'tombouctou',
#  'zhezkazgan',
#  'camacha',
#  'ushuaia',
#  'mecca',
#  'east london',
#  'hiranagar',
#  'hobyo',
#  'dikson',
#  'oistins',
#  'taolanaro',
#  'lagoa',
#  'olafsvik',
#  'urumqi',
#  'arraial do cabo',
#  'hermanus',
#  'oranjemund',
#  'ribeira grande',
#  'los llanos de aridane',
#  'senneterre',
#  'vila velha',
#  'nadym',
#  'ushuaia',
#  'taltal',
#  'atyrau',
#  'ponta do sol',
#  'saint george',
#  'taolanaro',
#  'tsihombe',
#  'carora',
#  'najran',
#  'ushuaia',
#  'upernavik',
#  'yar-sale',
#  'yar-sale',
#  'morristown',
#  'bambous virieux',
#  'illoqqortoormiut',
#  'nanortalik',
#  'mar del plata',
#  'moyale',
#  'taolanaro',
#  'attawapiskat',
#  'taolanaro',
#  'kavaratti',
#  'sao luiz gonzaga',
#  'inhambane',
#  'den helder',
#  'vardo',
#  'mar del plata',
#  'iguape',
#  'shebalino',
#  'san cristobal',
#  'tumannyy',
#  'qaanaaq',
#  'grenville',
#  'hermanus',
#  'turochak',
#  'saint-augustin',
#  'taolanaro',
#  'saint-joseph',
#  'mercedes',
#  'fort-shevchenko',
#  'ushuaia',
#  'arraial do cabo',
#  'hermanus',
#  'cape town',
#  'grindavik',
#  'kavaratti',
#  'faya',
#  'port alfred',
#  'marquette',
#  'angoche',
#  'salekhard',
#  'baghdad',
#  'mar del plata',
#  'governador dix-sept rosado',
#  'jamestown',
#  'saint-joseph',
#  'busselton',
#  'bambous virieux',
#  'cape town',
#  'bredasdorp',
#  'bilma',
#  'taolanaro',
#  'qaanaaq',
#  'hermanus',
#  'ponto novo',
#  'jamestown',
#  'bambous virieux',
#  'zmeinogorsk',
#  'adrar',
#  'sinjar',
#  'iqaluit',
#  'narsaq',
#  'amderma',
#  'rocha',
#  'ushuaia',
#  'bredasdorp',
#  'fort abbas',
#  'vozhd proletariata',
#  'lucapa',
#  'jamestown',
#  'bambous virieux',
#  'opuwo',
#  'nortelandia',
#  'cidreira',
#  'mar del plata',
#  'dingle',
#  'port alfred',
#  'bonavista',
#  'ushuaia',
#  'punta arenas',
#  'touros',
#  'hithadhoo',
#  'iranshahr',
#  'nueve de julio',
#  'taolanaro',
#  'kruisfontein',
#  'vastervik',
#  'port alfred',
#  'joensuu',
#  'noyabrsk',
#  'cape town',
#  'hermanus',
#  'port alfred',
#  'torbay',
#  'belushya guba',
#  'los llanos de aridane',
#  'ushuaia',
#  'cape town',
#  'qaanaaq',
#  'ust-tsilma',
#  'djambala',
#  'margate',
#  'shetpe',
#  'port alfred',
#  'hofn',
#  'stornoway',
#  'ribeira grande',
#  'cape town',
#  'aflu',
#  'mahebourg',
#  'gamba',
#  'hermanus',
#  'talavera de la reina',
#  'cape town',
#  'cape town',
#  'governador valadares',
#  'saint-pierre',
#  'taolanaro',
#  'saurimo',
#  'bonga',
#  'upernavik',
#  'taolanaro',
#  'bambous virieux',
#  'vila franca do campo',
#  'punta arenas',
#  'upernavik',
#  'galgani',
#  'georgetown',
#  'achisay',
#  'amderma',
#  'megion',
#  'cape town',
#  'cape town',
#  'koshki',
#  'cidreira',
#  'djambala',
#  'punta arenas',
#  'ha',
#  'georgetown',
#  'ballina',
#  'busselton',
#  'umzimvubu',
#  'praia da vitoria',
#  'beyneu',
#  'jamestown',
#  'letterkenny',
#  'port elizabeth',
#  'bathsheba',
#  'hermanus',
#  'umm lajj',
#  'tasiilaq',
#  'umzimvubu',
#  'silca',
#  'busselton',
#  'illoqqortoormiut',
#  'marcona',
#  'port-gentil',
#  'port elizabeth',
#  'attawapiskat',
#  'bredasdorp',
#  'port alfred',
#  'tessalit',
#  'illoqqortoormiut',
#  'bolshoye nagatkino',
#  'qaanaaq',
#  'busselton',
#  'tsihombe',
#  'ushuaia',
#  'cockburn town',
#  'port alfred',
#  'san luis',
#  'busselton',
#  'taolanaro',
#  'constitucion',
#  'beyneu',
#  'villa carlos paz',
#  'pervomayskoye',
#  'arraial do cabo',
#  'busselton',
#  'busselton',
#  'busselton',
#  'saint-michel-des-saints',
#  'bredasdorp',
#  'salalah',
#  'bredasdorp',
#  'malakal',
#  'nizhniy odes',
#  'el guante',
#  'mar del plata',
#  'taolanaro',
#  'saint-philippe',
#  'husavik',
#  'mar del plata',
#  'ushuaia',
#  'bathsheba',
#  'malakal',
#  'east london',
#  'hvittingfoss',
#  'lebu',
#  'hermanus',
#  'bathsheba',
#  'colombia',
#  'cape town',
#  'victoria',
#  'port elizabeth',
#  'sao felix do xingu',
#  'mont-de-marsan',
#  'mrirt',
#  'state college',
#  'barentsburg',
#  'mar del plata',
#  'kalmunai',
#  'paucartambo',
#  'ushuaia',
#  'florianopolis',
#  'guekedou',
#  'zhob',
#  'dale',
#  'humaita',
#  'qaanaaq',
#  'ushuaia',
#  'taolanaro',
#  'jamestown',
#  'illoqqortoormiut',
#  'cartagena',
#  'taolanaro',
#  'kolondieba',
#  'qaanaaq',
#  'ardistan',
#  'kuche',
#  'saldanha',
#  'barawe',
#  'rio claro',
#  'sisimiut',
#  'hithadhoo',
#  'tasiilaq',
#  'inhambane',
#  'havre-saint-pierre',
#  'voyvozh',
#  'barentsburg',
#  'bredasdorp',
#  'salalah',
#  'pitimbu',
#  'taolanaro',
#  'mahon',
#  'bambous virieux',
#  'ancud',
#  'atasu',
#  'cape town',
#  'halden',
#  'toliary',
#  'hithadhoo',
#  'ushuaia',
#  'ushuaia',
#  'mahon',
#  'viedma',
#  'cape town',
#  'sao filipe',
#  'port elizabeth',
#  'hofn',
#  'muros',
#  'bredasdorp',
#  'illoqqortoormiut',
#  'punta arenas',
#  'punta arenas',
#  'stokmarknes',
#  'taolanaro',
#  'iqaluit',
#  'impfondo',
#  'atar',
#  'saint-philippe',
#  'ushuaia',
#  'ushuaia',
#  'port elizabeth',
#  'mahebourg',
#  'port alfred',
#  'plettenberg bay',
#  'qaanaaq',
#  'longyearbyen',
#  'cape town',
#  'barcelona',
#  'tiznit',
#  'ushuaia',
#  'shirwal',
#  'illoqqortoormiut',
#  'odienne',
#  'bereda',
#  'umzimvubu',
#  'kharan',
#  'rio grande',
#  'krasnyy yar',
#  'jamestown',
#  'trairi',
#  'kutum',
#  'cape town',
#  'tabou',
#  'qaanaaq',
#  'caxito',
#  'luderitz',
#  'barentsburg',
#  'caravelas',
#  'souillac',
#  'port elizabeth',
#  'santa barbara',
#  'olinda',
#  'la romana',
#  'kruisfontein',
#  'mar del plata',
#  ...]
