# %% [markdown]
# ## Goal
# Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %%
import numpy as np

#Generate 2000 random lattitudes and longitudes
latitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
coordinates = list(zip(latitudes,longitudes))

# %%
from config import weather_api_key
from citipy import citipy

#Create base url string
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#using citipy to map coordinates to nearest cities
cityList = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #making sure we don't have duplicates
    if city not in cityList:
        cityList.append(city)
len(cityList)
# Out:
# 768

# %%
import time
import requests
from datetime import datetime
cityData = []

for i, city in enumerate(cityList):
    recordCounter = 1
    setCounter = 1
    if (i % 50 == 0 and i >= 50):
        recordCounter += 1
        setCounter += 1
        time.sleep(60)
    try:
        print("getting " + city)
        cityUrl = url + "&q=" + city.replace(" ","+")
        cityWeather = requests.get(cityUrl).json()
        city_lat = cityWeather["coord"]["lat"]
        city_lng = cityWeather["coord"]["lon"]
        city_max_temp = cityWeather["main"]["temp_max"]
        city_humidity = cityWeather["main"]["humidity"]
        city_clouds = cityWeather["clouds"]["all"]
        city_wind = cityWeather["wind"]["speed"]
        cityDesc = cityWeather["weather"][0]["description"]
        city_country = cityWeather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(cityWeather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        cityData.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Description": cityDesc})
    except:
        print("failed")
cityData
# Out:
# getting east london
# getting kegayli
# failed
# getting antsohihy
# getting victoria
# getting mar del plata
# getting stodolishche
# getting jamestown
# getting port shepstone
# getting bengkulu
# getting geraldton
# getting elizabeth city
# getting ardistan
# failed
# getting cazaje
# failed
# getting aswan
# getting barentsburg
# failed
# getting alice
# getting souillac
# getting upernavik
# getting ribeira grande
# getting mugumu
# getting coquimbo
# getting santa rosa
# getting mbekenyera
# getting bereda
# getting hermanus
# getting qaanaaq
# getting port alfred
# getting richards bay
# getting ushuaia
# getting birao
# getting taoudenni
# getting domoni
# getting lagoa
# getting mozhga
# getting tumannyy
# failed
# getting cap-chat
# getting cockburn town
# getting le port
# getting margate
# getting mangrol
# getting hualmay
# getting trincomalee
# getting ilulissat
# getting narsaq
# getting nicolas bravo
# getting segou
# getting tasiilaq
# getting teslic
# getting saint-philippe
# getting sorland
# getting grand river south east
# failed
# getting oussouye
# getting mehamn
# getting marcona
# failed
# getting hamilton
# getting gananoque
# getting carbonia
# getting praia da vitoria
# getting sidi bu zayd
# failed
# getting kuusamo
# getting hithadhoo
# getting busselton
# getting nioro
# getting codrington
# getting trairi
# getting vryburg
# getting micheweni
# getting dikson
# getting novorzhev
# getting umzimvubu
# failed
# getting rio grande
# getting cape town
# getting sao filipe
# getting sol-iletsk
# getting boldumsaz
# getting touros
# getting chingirlau
# getting yar-sale
# getting moshenskoye
# getting dingle
# getting mitsamiouli
# getting manbij
# getting porlamar
# getting longyearbyen
# getting saldanha
# getting nantucket
# getting carnarvon
# getting illoqqortoormiut
# failed
# getting mgandu
# getting umm lajj
# getting pinsk
# getting strezhevoy
# getting bredasdorp
# getting cidreira
# getting san luis
# getting henties bay
# getting turtkul
# failed
# getting bandarbeyla
# getting lakhdenpokhya
# getting kruisfontein
# getting roald
# getting san ramon
# getting sisimiut
# getting abalak
# getting arraial do cabo
# getting yining
# getting pangnirtung
# getting cascais
# getting astolfo dutra
# getting rodrigues alves
# getting saint-alexandre
# getting ornskoldsvik
# getting ambovombe
# getting vila franca do campo
# getting marathopolis
# failed
# getting berlevag
# getting egra
# getting noyabrsk
# getting matara
# getting dawlatabad
# getting kavaratti
# getting yako
# getting port elizabeth
# getting punta arenas
# getting opuwo
# getting luanda
# getting aragarcas
# getting laguna
# getting omboue
# getting beloha
# getting porbandar
# getting asfi
# getting pavilosta
# getting qaqortoq
# getting bathsheba
# getting tsihombe
# failed
# getting attawapiskat
# failed
# getting coruripe
# getting aksu
# getting wilmington
# getting nakonde
# getting taybad
# getting castro
# getting constitucion
# getting kisangani
# getting sur
# getting zinder
# getting los llanos de aridane
# getting taolanaro
# failed
# getting nicoya
# getting sao miguel do araguaia
# getting campo largo
# getting husavik
# getting cayenne
# getting kharan
# getting ust-kulom
# getting akureyri
# getting ostrovnoy
# getting kalino
# getting tiznit
# getting kerman
# getting ayagoz
# getting sarakhs
# getting burgos
# getting namibe
# getting sao felix do xingu
# getting sainte-anne-des-monts
# getting plettenberg bay
# getting lucera
# getting belomorsk
# getting san pedro
# getting adre
# getting abu samrah
# getting bedford
# getting qeshm
# getting belushya guba
# failed
# getting nizhnevartovsk
# getting mahebourg
# getting bambous virieux
# getting saint-augustin
# getting bababe
# failed
# getting harper
# getting prainha
# getting saint george
# getting bubaque
# getting george town
# getting belyy yar
# getting anloga
# getting sept-iles
# getting vestmannaeyjar
# getting gao
# getting karkaralinsk
# failed
# getting dzilam gonzalez
# getting kaputa
# getting ancud
# getting ponta do sol
# getting kuche
# failed
# getting sabha
# getting saint anthony
# getting macau
# getting lasa
# getting hobyo
# getting eyl
# getting la asuncion
# getting camacupa
# getting chuy
# getting dudinka
# getting beyneu
# getting serebryansk
# getting salalah
# getting inhambane
# getting porto torres
# getting tazovskiy
# getting luderitz
# getting gamba
# getting santa fe
# getting klaksvik
# getting nanortalik
# getting antofagasta
# getting georgetown
# getting bridlington
# getting torbay
# getting leh
# getting arroyo
# getting dwarka
# getting la macarena
# getting maragogi
# getting kuytun
# getting komsomolets
# getting riyadh
# getting concepcion
# getting gat
# getting mercedes
# getting rocha
# getting keskin
# getting papayal
# getting natal
# getting tapaua
# failed
# getting mvangue
# getting meulaboh
# getting kajaani
# getting brigantine
# getting vangaindrano
# getting mocambique
# failed
# getting marsh harbour
# getting amderma
# failed
# getting saint-pierre
# getting gourdon
# getting agua buena
# getting karpathos
# getting malanje
# getting maceio
# getting ilo
# getting coremas
# getting itarema
# getting rawson
# getting louisbourg
# failed
# getting quatre cocos
# getting iisalmi
# getting marienburg
# getting veliko gradiste
# getting walvis bay
# getting lesnyye polyany
# getting tambura
# getting soyo
# getting peniche
# getting kamenka
# getting maghama
# failed
# getting viedma
# getting candido mendes
# getting saint-joseph
# getting porto novo
# getting marawi
# getting macusani
# getting leshukonskoye
# getting minas
# getting vila do maio
# getting caxito
# getting loviisa
# getting chapais
# getting boa vista
# getting guna
# getting vardo
# getting tocopilla
# getting cap malheureux
# getting strangnas
# getting san nicolas
# getting domat
# getting kabo
# getting sembe
# getting florianopolis
# getting ylivieska
# getting tarudant
# failed
# getting barra do bugres
# getting blagoyevo
# getting faya
# getting san carlos de bariloche
# getting acari
# getting gualaquiza
# getting nemesnadudvar
# getting praia
# getting thinadhoo
# getting basoko
# getting vila velha
# getting batavia
# getting mahajanga
# getting grindavik
# getting sistranda
# getting arlit
# getting tanout
# getting vrede
# getting tucuma
# getting moose factory
# getting macapa
# getting fontem
# getting qafsah
# failed
# getting ati
# getting shu
# getting santa maria
# getting bat khela
# getting doka
# getting desbiens
# getting slavonice
# getting pimentel
# getting bolsheustikinskoye
# failed
# getting rudbar
# getting tokonou
# getting brae
# getting puerto montt
# getting zhezkazgan
# getting stilfontein
# getting shiringushi
# getting severodvinsk
# getting edwardsville
# getting lampa
# getting detchino
# getting pastavy
# getting huambo
# getting maykain
# failed
# getting caravelas
# getting maimon
# failed
# getting ust-tsilma
# getting srivardhan
# getting le moule
# getting inderborskiy
# failed
# getting port blair
# getting penzance
# getting coihaique
# getting kalabo
# getting mount pleasant
# getting najran
# getting calama
# getting niamey
# getting fort myers beach
# getting bargal
# failed
# getting andenes
# getting marsa matruh
# getting oudtshoorn
# getting imbituba
# getting mangai
# getting limon
# getting tibati
# getting dekoa
# failed
# getting tir pol
# failed
# getting tabuk
# getting tuggurt
# failed
# getting sindor
# getting itaituba
# getting rincon
# getting gorlice
# getting malangali
# getting rosita
# getting iberia
# getting baijiantan
# getting jijiga
# getting burica
# failed
# getting awbari
# getting tignere
# getting atar
# getting carahue
# getting pisco
# getting kaduy
# getting pyaozerskiy
# getting nuuk
# getting gualan
# getting aripuana
# getting malanville
# getting hambantota
# getting luwingu
# getting jurado
# getting fort wayne
# getting araouane
# getting kasese
# getting chadiza
# getting bocas del toro
# getting maldonado
# getting troitsko-pechorsk
# getting george
# getting gulu
# getting catamarca
# getting comodoro rivadavia
# getting kigorobya
# getting port-gentil
# getting shostka
# getting tafresh
# getting maniitsoq
# getting phalaborwa
# getting khandbari
# getting oranjemund
# getting forestville
# getting pitimbu
# getting curaca
# getting saquarema
# getting zarnesti
# getting synya
# getting sioux lookout
# getting cochrane
# getting sao joao da barra
# getting yazman
# getting antalaha
# getting ugoofaaru
# getting bure
# getting toropets
# getting urdzhar
# failed
# getting belmonte
# getting mahibadhoo
# getting matadi
# getting torit
# getting constantine
# getting lebu
# getting benton harbor
# getting mlimba
# getting acarau
# getting galle
# getting orastioara de sus
# getting sibay
# getting puerto carreno
# getting piacabucu
# getting makat
# getting trelew
# getting abomey-calavi
# getting porto franco
# getting kasongo
# getting waddan
# getting liverpool
# getting borovikha
# getting muana
# getting ringebu
# getting rundu
# getting mitu
# getting totness
# getting shonguy
# getting mahon
# getting sorvag
# failed
# getting santiago
# getting cubulero
# failed
# getting hurghada
# getting staroutkinsk
# getting aflu
# failed
# getting lena
# getting impfondo
# getting grand gaube
# getting talara
# getting laukaa
# getting spasskoye
# getting pedasi
# getting tekeli
# getting yialos
# failed
# getting dabola
# getting shujaabad
# getting mbanza-ngungu
# getting teruel
# getting waw
# getting sedelnikovo
# failed
# getting mana
# getting verkhnetulomskiy
# getting mkushi
# getting brazzaville
# getting ascension
# getting dakar
# getting arki
# getting xacmaz
# getting moroni
# getting hofn
# getting bolshaya atnya
# failed
# getting novoagansk
# getting zaykovo
# getting nara
# getting andros town
# getting petawawa
# getting tahoua
# getting nesna
# getting kargasok
# getting kashary
# getting suponevo
# getting taltal
# getting buraydah
# getting olinda
# getting saint-francois
# getting kintampo
# getting nanuque
# getting garowe
# getting kataysk
# getting keti bandar
# getting tukrah
# getting moroto
# getting lamu
# getting borama
# failed
# getting puerto leguizamo
# getting bosaso
# getting bekhteyevka
# getting hammerfest
# getting santa vitoria
# getting san cristobal
# getting necochea
# getting baldeogarh
# getting kalulushi
# getting talcahuano
# getting jumla
# getting quelimane
# getting thompson
# getting morondava
# getting luziania
# getting nioki
# getting santa cruz
# getting pachino
# getting novo aripuana
# getting oranjestad
# getting mayumba
# getting nouadhibou
# getting kurtamysh
# getting nadvoitsy
# getting lisakovsk
# getting marzuq
# getting zharkent
# getting xapuri
# getting gamboma
# getting agirish
# getting port hawkesbury
# getting muli
# getting karlstad
# getting arrifes
# getting san-pedro
# getting sukhumi
# getting sohag
# getting iqaluit
# getting ndele
# getting charyshskoye
# getting mantua
# getting punta alta
# getting vestmanna
# getting chateau-thierry
# getting altagracia de orituco
# getting weligama
# getting geresk
# failed
# getting denia
# getting nusaybin
# getting behshahr
# getting poshekhonye
# getting marfino
# getting grao mogol
# getting zhanakorgan
# getting uchiza
# getting polyarnyy
# getting sicuani
# getting caluquembe
# getting kondinskoye
# getting tchamba
# getting letlhakane
# getting hennebont
# getting abu kamal
# getting eatonton
# getting san andres
# getting rosetta
# getting moengo
# getting maarianhamina
# getting paucartambo
# failed
# getting tosya
# getting cervo
# getting muros
# getting kurchum
# getting sohbatpur
# getting amapa
# getting rio gallegos
# getting cleethorpes
# getting naumburg
# getting abu dhabi
# getting thaba nchu
# getting almeirim
# getting nizhniye vyazovyye
# getting balkanabat
# getting canavieiras
# getting tamsweg
# getting hunza
# failed
# getting karamay
# failed
# getting clyde river
# getting eenhana
# getting iracoubo
# getting willowmore
# getting borba
# getting afmadu
# failed
# getting madimba
# getting kirkwall
# getting the valley
# getting nenagh
# getting kibakwe
# getting maputo
# getting kaura namoda
# getting soller
# getting berezivka
# getting ampanihy
# getting gazojak
# getting atocha
# getting bantry
# getting gararu
# getting olafsvik
# getting bud
# getting zavyalovo
# getting mvomero
# getting trujillo
# getting iquique
# getting varzelandia
# getting hendijan
# failed
# getting kargopol
# getting boende
# getting dzaoudzi
# getting amarante
# getting tessalit
# getting kilindoni
# getting puquio
# getting derzhavinsk
# getting zabol
# getting balad
# getting sayat
# getting dedougou
# getting vreed en hoop
# failed
# getting kemijarvi
# getting ouadda
# getting itatinga
# getting marinette
# getting manta
# getting kotido
# getting keuruu
# getting sysert
# getting kushmurun
# getting mwanza
# getting lodeynoye pole
# getting gurgan
# failed
# getting pervomayskoye
# getting monrovia
# getting puerto ayacucho
# getting lagoa vermelha
# getting sao sebastiao
# getting playas
# getting mao
# getting eydhafushi
# getting inyonga
# getting solovetskiy
# failed
# getting santa vitoria do palmar
# getting puerto suarez
# getting salinas
# getting bjornevatn
# getting marsabit
# getting adrar
# getting palermo
# getting zemio
# getting riohacha
# getting gua
# getting arica
# getting suda
# getting warqla
# failed
# getting gorele
# getting valjala
# failed
# getting parainen
# getting agadez
# getting balashov
# getting camocim
# getting sehithwa
# getting tarko-sale
# getting tombouctou
# getting jadu
# getting dhidhdhoo
# getting nyandoma
# getting mosetse
# getting cabo rojo
# getting manadhoo
# getting sayyan
# getting santander
# getting juba
# getting concepcion del uruguay
# getting kinkala
# getting stolin
# getting tromso
# getting chapleau
# getting tchibanga
# getting barawe
# failed
# getting vytegra
# getting oxford
# getting qasigiannguit
# getting miranda
# getting sumter
# getting kismayo
# getting hindoria
# getting vesele
# getting novyy urengoy
# getting kuopio
# getting zorritos
# getting san carlos
# getting piripiri
# getting hvide sande
# getting general pico
# getting altay
# getting hovin
# getting rokytne
# getting kutum
# getting varangaon
# getting belyy
# getting idukki
# getting svetlopolyansk
# getting sherbakul
# getting axim
# getting barreirinhas
# getting baft
# getting alta floresta
# getting paulo afonso
# getting mahbubabad
# getting deogarh
# getting malwan
# failed
# getting saurimo
# getting conceicao do araguaia
# getting pokaran
# getting robertsport
# getting marand
# getting paamiut
# getting moa
# getting aksarka
# getting cacapava do sul
# getting abong mbang
# getting cockburn harbour
# failed
# getting kanniyakumari
# getting westport
# getting sangre grande
# getting igrim
# getting pampas
# getting demidov
# getting skalistyy
# failed
# getting nokaneng
# getting bagli
# getting jardim
# getting manjacaze
# getting waldoboro
# getting altamira
# getting sambava
# getting dedza
# getting vigrestad
# getting chabahar
# getting buchanan
# getting lipari
# getting karatau
# getting shagamu
# getting urumqi
# getting yenagoa
# getting kidal
# getting jujuy
# failed
# getting berdyaush
# getting llaillay
# getting itacoatiara
# getting nassau
# [{'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 67.14,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Antsohihy',
#   'Lat': -14.8796,
#   'Lng': 47.9875,
#   'Max Temp': 91.92,
#   'Humidity': 39,
#   'Cloudiness': 54,
#   'Wind Speed': 9.93,
#   'Country': 'MG',
#   'Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 84.18,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 17,
#   'Country': 'HK',
#   'Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 44.94,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'AR',
#   'Description': 'broken clouds'},
#  {'City': 'Stodolishche',
#   'Lat': 54.1859,
#   'Lng': 32.6492,
#   'Max Temp': 56.48,
#   'Humidity': 56,
#   'Cloudiness': 90,
#   'Wind Speed': 14.07,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 63.99,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Description': 'fog'},
#  {'City': 'Port Shepstone',
#   'Lat': -30.7414,
#   'Lng': 30.455,
#   'Max Temp': 63.12,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 17.47,
#   'Country': 'ZA',
#   'Description': 'light rain'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 83.39,
#   'Humidity': 71,
#   'Cloudiness': 58,
#   'Wind Speed': 4.43,
#   'Country': 'ID',
#   'Description': 'broken clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.61,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 75.22,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 92.19,
#   'Humidity': 10,
#   'Cloudiness': 2,
#   'Wind Speed': 16.37,
#   'Country': 'EG',
#   'Description': 'clear sky'},
#  {'City': 'Alice',
#   'Lat': 27.7523,
#   'Lng': -98.0697,
#   'Max Temp': 80.33,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 79.18,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Description': 'broken clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 31.12,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'GL',
#   'Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Mugumu',
#   'Lat': -1.85,
#   'Lng': 34.7,
#   'Max Temp': 80.24,
#   'Humidity': 45,
#   'Cloudiness': 81,
#   'Wind Speed': 3,
#   'Country': 'TZ',
#   'Description': 'broken clouds'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 53.33,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Description': 'mist'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 83.1,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 3.91,
#   'Country': 'PH',
#   'Description': 'light rain'},
#  {'City': 'Mbekenyera',
#   'Lat': -10,
#   'Lng': 38.9833,
#   'Max Temp': 86.29,
#   'Humidity': 40,
#   'Cloudiness': 89,
#   'Wind Speed': 3.2,
#   'Country': 'TZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 64.58,
#   'Humidity': 89,
#   'Cloudiness': 65,
#   'Wind Speed': 4.83,
#   'Country': 'ES',
#   'Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 66.79,
#   'Humidity': 66,
#   'Cloudiness': 46,
#   'Wind Speed': 7.87,
#   'Country': 'ZA',
#   'Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 16.72,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Country': 'GL',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 69.19,
#   'Humidity': 67,
#   'Cloudiness': 3,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 66.65,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 22.66,
#   'Country': 'ZA',
#   'Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.06,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'AR',
#   'Description': 'broken clouds'},
#  {'City': 'Birao',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 98.55,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'CF',
#   'Description': 'overcast clouds'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 100,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99,
#   'Country': 'ML',
#   'Description': 'clear sky'},
#  {'City': 'Domoni',
#   'Lat': -12.2569,
#   'Lng': 44.5319,
#   'Max Temp': 81.68,
#   'Humidity': 74,
#   'Cloudiness': 74,
#   'Wind Speed': 10.07,
#   'Country': 'KM',
#   'Description': 'broken clouds'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 61.77,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.27,
#   'Country': 'PT',
#   'Description': 'overcast clouds'},
#  {'City': 'Mozhga',
#   'Lat': 56.4447,
#   'Lng': 52.2276,
#   'Max Temp': 40.77,
#   'Humidity': 65,
#   'Cloudiness': 98,
#   'Wind Speed': 9.46,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Cap-Chat',
#   'Lat': 49.1001,
#   'Lng': -66.6821,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 43,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Description': 'scattered clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 79.32,
#   'Humidity': 78,
#   'Cloudiness': 95,
#   'Wind Speed': 18.61,
#   'Country': 'TC',
#   'Description': 'overcast clouds'},
#  {'City': 'Le Port',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 82.4,
#   'Humidity': 67,
#   'Cloudiness': 10,
#   'Wind Speed': 3.02,
#   'Country': 'RE',
#   'Description': 'clear sky'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 66.11,
#   'Humidity': 70,
#   'Cloudiness': 51,
#   'Wind Speed': 6.49,
#   'Country': 'GB',
#   'Description': 'broken clouds'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 86.81,
#   'Humidity': 71,
#   'Cloudiness': 39,
#   'Wind Speed': 20.29,
#   'Country': 'IN',
#   'Description': 'scattered clouds'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 62.76,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 4.36,
#   'Country': 'PE',
#   'Description': 'overcast clouds'},
#  {'City': 'Trincomalee',
#   'Lat': 8.5711,
#   'Lng': 81.2335,
#   'Max Temp': 91.76,
#   'Humidity': 52,
#   'Cloudiness': 96,
#   'Wind Speed': 20.96,
#   'Country': 'LK',
#   'Description': 'overcast clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 42.82,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Country': 'GL',
#   'Description': 'light rain'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 35.82,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.93,
#   'Country': 'GL',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Nicolas Bravo',
#   'Lat': 18.45,
#   'Lng': -88.9167,
#   'Max Temp': 79.29,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Country': 'MX',
#   'Description': 'overcast clouds'},
#  {'City': 'Segou',
#   'Lat': 13.4317,
#   'Lng': -6.2157,
#   'Max Temp': 92.35,
#   'Humidity': 33,
#   'Cloudiness': 80,
#   'Wind Speed': 10.09,
#   'Country': 'ML',
#   'Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 33.96,
#   'Humidity': 67,
#   'Cloudiness': 80,
#   'Wind Speed': 3.09,
#   'Country': 'GL',
#   'Description': 'broken clouds'},
#  {'City': 'Teslic',
#   'Lat': 44.6064,
#   'Lng': 17.8597,
#   'Max Temp': 73.18,
#   'Humidity': 58,
#   'Cloudiness': 69,
#   'Wind Speed': 5.53,
#   'Country': 'BA',
#   'Description': 'broken clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 81.99,
#   'Humidity': 77,
#   'Cloudiness': 15,
#   'Wind Speed': 12.88,
#   'Country': 'RE',
#   'Description': 'light rain'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 46.26,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Oussouye',
#   'Lat': 12.485,
#   'Lng': -16.5469,
#   'Max Temp': 80.78,
#   'Humidity': 52,
#   'Cloudiness': 90,
#   'Wind Speed': 7.36,
#   'Country': 'SN',
#   'Description': 'overcast clouds'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 42.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 66.83,
#   'Humidity': 97,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'mist'},
#  {'City': 'Gananoque',
#   'Lat': 44.3334,
#   'Lng': -76.1661,
#   'Max Temp': 63.99,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 5.61,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Carbonia',
#   'Lat': 39.1672,
#   'Lng': 8.5222,
#   'Max Temp': 88.02,
#   'Humidity': 26,
#   'Cloudiness': 2,
#   'Wind Speed': 7.78,
#   'Country': 'IT',
#   'Description': 'clear sky'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64.76,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.29,
#   'Country': 'PT',
#   'Description': 'mist'},
#  {'City': 'Kuusamo',
#   'Lat': 65.9667,
#   'Lng': 29.1833,
#   'Max Temp': 41.04,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'FI',
#   'Description': 'shower rain'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.91,
#   'Humidity': 70,
#   'Cloudiness': 80,
#   'Wind Speed': 14.65,
#   'Country': 'MV',
#   'Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 61.38,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 22.19,
#   'Country': 'AU',
#   'Description': 'overcast clouds'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 84.31,
#   'Humidity': 38,
#   'Cloudiness': 92,
#   'Wind Speed': 5.93,
#   'Country': 'GM',
#   'Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 48.11,
#   'Humidity': 91,
#   'Cloudiness': 6,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Description': 'clear sky'},
#  {'City': 'Trairi',
#   'Lat': -3.2778,
#   'Lng': -39.2689,
#   'Max Temp': 74.01,
#   'Humidity': 93,
#   'Cloudiness': 86,
#   'Wind Speed': 4.63,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Vryburg',
#   'Lat': -26.9566,
#   'Lng': 24.7284,
#   'Max Temp': 60.87,
#   'Humidity': 51,
#   'Cloudiness': 5,
#   'Wind Speed': 8.75,
#   'Country': 'ZA',
#   'Description': 'clear sky'},
#  {'City': 'Micheweni',
#   'Lat': -4.9667,
#   'Lng': 39.8333,
#   'Max Temp': 83.52,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 13.96,
#   'Country': 'TZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 29.16,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.52,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Novorzhev',
#   'Lat': 57.0294,
#   'Lng': 29.3338,
#   'Max Temp': 55.58,
#   'Humidity': 39,
#   'Cloudiness': 70,
#   'Wind Speed': 10.49,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 43.95,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 5.5,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 68.11,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Description': 'few clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 71.04,
#   'Humidity': 78,
#   'Cloudiness': 62,
#   'Wind Speed': 10.02,
#   'Country': 'CV',
#   'Description': 'broken clouds'},
#  {'City': 'Sol-Iletsk',
#   'Lat': 51.1631,
#   'Lng': 54.9918,
#   'Max Temp': 54.32,
#   'Humidity': 52,
#   'Cloudiness': 100,
#   'Wind Speed': 12.68,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Boldumsaz',
#   'Lat': 42.1282,
#   'Lng': 59.671,
#   'Max Temp': 71.65,
#   'Humidity': 32,
#   'Cloudiness': 76,
#   'Wind Speed': 6.98,
#   'Country': 'TM',
#   'Description': 'broken clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 76.08,
#   'Humidity': 88,
#   'Cloudiness': 63,
#   'Wind Speed': 11.65,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Chingirlau',
#   'Lat': 51.095,
#   'Lng': 54.0814,
#   'Max Temp': 55.35,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'KZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 37.08,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 19.1,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Moshenskoye',
#   'Lat': 58.5102,
#   'Lng': 34.5911,
#   'Max Temp': 48.6,
#   'Humidity': 32,
#   'Cloudiness': 10,
#   'Wind Speed': 9.01,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 80.67,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Country': 'PH',
#   'Description': 'overcast clouds'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 81.91,
#   'Humidity': 68,
#   'Cloudiness': 60,
#   'Wind Speed': 7.31,
#   'Country': 'KM',
#   'Description': 'broken clouds'},
#  {'City': 'Manbij',
#   'Lat': 36.5281,
#   'Lng': 37.9549,
#   'Max Temp': 88.74,
#   'Humidity': 9,
#   'Cloudiness': 74,
#   'Wind Speed': 15.17,
#   'Country': 'SY',
#   'Description': 'broken clouds'},
#  {'City': 'Porlamar',
#   'Lat': 10.958,
#   'Lng': -63.8491,
#   'Max Temp': 78.89,
#   'Humidity': 89,
#   'Cloudiness': 17,
#   'Wind Speed': 5.75,
#   'Country': 'VE',
#   'Description': 'few clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 37.24,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'SJ',
#   'Description': 'broken clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 68.05,
#   'Humidity': 65,
#   'Cloudiness': 21,
#   'Wind Speed': 2.89,
#   'Country': 'ZA',
#   'Description': 'few clouds'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 62.71,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'mist'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 73.11,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 16.71,
#   'Country': 'AU',
#   'Description': 'clear sky'},
#  {'City': 'Mgandu',
#   'Lat': -5.95,
#   'Lng': 34.1333,
#   'Max Temp': 79.63,
#   'Humidity': 40,
#   'Cloudiness': 89,
#   'Wind Speed': 7.47,
#   'Country': 'TZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 83.12,
#   'Humidity': 58,
#   'Cloudiness': 3,
#   'Wind Speed': 20.07,
#   'Country': 'SA',
#   'Description': 'clear sky'},
#  {'City': 'Pinsk',
#   'Lat': 52.1229,
#   'Lng': 26.0951,
#   'Max Temp': 48.79,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 15.32,
#   'Country': 'BY',
#   'Description': 'overcast clouds'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 74.97,
#   'Humidity': 41,
#   'Cloudiness': 13,
#   'Wind Speed': 16.69,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 67.05,
#   'Humidity': 52,
#   'Cloudiness': 47,
#   'Wind Speed': 8.41,
#   'Country': 'ZA',
#   'Description': 'scattered clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 54.95,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 2.13,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'San Luis',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 52.97,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Country': 'AR',
#   'Description': 'overcast clouds'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 73.94,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 6.58,
#   'Country': 'NA',
#   'Description': 'clear sky'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 98.06,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 17.83,
#   'Country': 'SO',
#   'Description': 'overcast clouds'},
#  {'City': 'Lakhdenpokhya',
#   'Lat': 61.5198,
#   'Lng': 30.1992,
#   'Max Temp': 50.31,
#   'Humidity': 34,
#   'Cloudiness': 2,
#   'Wind Speed': 3.76,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 66.88,
#   'Humidity': 55,
#   'Cloudiness': 16,
#   'Wind Speed': 1.61,
#   'Country': 'ZA',
#   'Description': 'few clouds'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 60.91,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NO',
#   'Description': 'clear sky'},
#  {'City': 'San Ramon',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 58.51,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 38.03,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 34.76,
#   'Country': 'GL',
#   'Description': 'light rain'},
#  {'City': 'Abalak',
#   'Lat': 58.1286,
#   'Lng': 68.5944,
#   'Max Temp': 47.03,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.89,
#   'Country': 'RU',
#   'Description': 'light rain'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 62.46,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Yining',
#   'Lat': 29.0361,
#   'Lng': 114.5636,
#   'Max Temp': 67.73,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Country': 'CN',
#   'Description': 'light rain'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 23.92,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Cascais',
#   'Lat': 38.6979,
#   'Lng': -9.4215,
#   'Max Temp': 67.51,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 25.01,
#   'Country': 'PT',
#   'Description': 'broken clouds'},
#  {'City': 'Astolfo Dutra',
#   'Lat': -21.3153,
#   'Lng': -42.8622,
#   'Max Temp': 59.67,
#   'Humidity': 92,
#   'Cloudiness': 16,
#   'Wind Speed': 1.54,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Rodrigues Alves',
#   'Lat': -7.738,
#   'Lng': -72.6509,
#   'Max Temp': 72.59,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Saint-Alexandre',
#   'Lat': 44.2278,
#   'Lng': 4.6214,
#   'Max Temp': 84.97,
#   'Humidity': 36,
#   'Cloudiness': 77,
#   'Wind Speed': 4.83,
#   'Country': 'FR',
#   'Description': 'broken clouds'},
#  {'City': 'Ornskoldsvik',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 59.95,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'SE',
#   'Description': 'few clouds'},
#  {'City': 'Ambovombe',
#   'Lat': -25.1667,
#   'Lng': 46.0833,
#   'Max Temp': 80.26,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'MG',
#   'Description': 'clear sky'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 70.2,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 3.38,
#   'Country': 'PT',
#   'Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 42.75,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Egra',
#   'Lat': 50.0796,
#   'Lng': 12.3739,
#   'Max Temp': 66.29,
#   'Humidity': 59,
#   'Cloudiness': 41,
#   'Wind Speed': 3.98,
#   'Country': 'CZ',
#   'Description': 'scattered clouds'},
#  {'City': 'Noyabrsk',
#   'Lat': 63.1994,
#   'Lng': 75.4507,
#   'Max Temp': 64.51,
#   'Humidity': 43,
#   'Cloudiness': 64,
#   'Wind Speed': 25.32,
#   'Country': 'RU',
#   'Description': 'broken clouds'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 83.71,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 15.08,
#   'Country': 'LK',
#   'Description': 'few clouds'},
#  {'City': 'Dawlatabad',
#   'Lat': 36.4141,
#   'Lng': 64.9053,
#   'Max Temp': 72.9,
#   'Humidity': 28,
#   'Cloudiness': 9,
#   'Wind Speed': 9.91,
#   'Country': 'AF',
#   'Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 82.11,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 16.91,
#   'Country': 'IN',
#   'Description': 'moderate rain'},
#  {'City': 'Yako',
#   'Lat': 12.9667,
#   'Lng': -2.2667,
#   'Max Temp': 94.08,
#   'Humidity': 33,
#   'Cloudiness': 87,
#   'Wind Speed': 13.22,
#   'Country': 'BF',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 69.1,
#   'Humidity': 62,
#   'Cloudiness': 31,
#   'Wind Speed': 2.19,
#   'Country': 'ZA',
#   'Description': 'scattered clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 33.91,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Description': 'scattered clouds'},
#  {'City': 'Opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 72.48,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 12.39,
#   'Country': 'NA',
#   'Description': 'clear sky'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 76.15,
#   'Humidity': 70,
#   'Cloudiness': 77,
#   'Wind Speed': 5.79,
#   'Country': 'AO',
#   'Description': 'broken clouds'},
#  {'City': 'Aragarcas',
#   'Lat': -15.8975,
#   'Lng': -52.2508,
#   'Max Temp': 51.15,
#   'Humidity': 59,
#   'Cloudiness': 22,
#   'Wind Speed': 2.3,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 62.64,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 81.34,
#   'Humidity': 69,
#   'Cloudiness': 80,
#   'Wind Speed': 9.62,
#   'Country': 'GA',
#   'Description': 'broken clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 87.21,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 4.25,
#   'Country': 'MG',
#   'Description': 'clear sky'},
#  {'City': 'Porbandar',
#   'Lat': 21.6422,
#   'Lng': 69.6093,
#   'Max Temp': 87.01,
#   'Humidity': 71,
#   'Cloudiness': 42,
#   'Wind Speed': 22.1,
#   'Country': 'IN',
#   'Description': 'scattered clouds'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 70.95,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 14.72,
#   'Country': 'MA',
#   'Description': 'overcast clouds'},
#  {'City': 'Pavilosta',
#   'Lat': 56.8879,
#   'Lng': 21.1859,
#   'Max Temp': 51.71,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Country': 'LV',
#   'Description': 'overcast clouds'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 37.26,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 16.78,
#   'Country': 'GL',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 81.21,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'BB',
#   'Description': 'few clouds'},
#  {'City': 'Coruripe',
#   'Lat': -10.1256,
#   'Lng': -36.1756,
#   'Max Temp': 77.4,
#   'Humidity': 76,
#   'Cloudiness': 87,
#   'Wind Speed': 14.47,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 86.95,
#   'Humidity': 15,
#   'Cloudiness': 100,
#   'Wind Speed': 12.46,
#   'Country': 'CN',
#   'Description': 'overcast clouds'},
#  {'City': 'Wilmington',
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp': 75.11,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Nakonde',
#   'Lat': -9.3421,
#   'Lng': 32.745,
#   'Max Temp': 78.53,
#   'Humidity': 43,
#   'Cloudiness': 47,
#   'Wind Speed': 1.86,
#   'Country': 'ZM',
#   'Description': 'scattered clouds'},
#  {'City': 'Taybad',
#   'Lat': 34.74,
#   'Lng': 60.7756,
#   'Max Temp': 71.56,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 21.16,
#   'Country': 'IR',
#   'Description': 'clear sky'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 41.2,
#   'Humidity': 81,
#   'Cloudiness': 6,
#   'Wind Speed': 2.93,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 52.9,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'CL',
#   'Description': 'overcast clouds'},
#  {'City': 'Kisangani',
#   'Lat': 0.5167,
#   'Lng': 25.2,
#   'Max Temp': 92.28,
#   'Humidity': 43,
#   'Cloudiness': 76,
#   'Wind Speed': 0.63,
#   'Country': 'CD',
#   'Description': 'broken clouds'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 101.79,
#   'Humidity': 31,
#   'Cloudiness': 3,
#   'Wind Speed': 4.94,
#   'Country': 'OM',
#   'Description': 'clear sky'},
#  {'City': 'Zinder',
#   'Lat': 13.8072,
#   'Lng': 8.9881,
#   'Max Temp': 98.56,
#   'Humidity': 22,
#   'Cloudiness': 47,
#   'Wind Speed': 4.61,
#   'Country': 'NE',
#   'Description': 'dust'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 67.75,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'ES',
#   'Description': 'few clouds'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 75.92,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'CR',
#   'Description': 'overcast clouds'},
#  {'City': 'Sao Miguel Do Araguaia',
#   'Lat': -13.275,
#   'Lng': -50.1628,
#   'Max Temp': 56.12,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.81,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Campo Largo',
#   'Lat': -25.4586,
#   'Lng': -49.5283,
#   'Max Temp': 44.11,
#   'Humidity': 89,
#   'Cloudiness': 17,
#   'Wind Speed': 2.57,
#   'Country': 'BR',
#   'Description': 'few clouds'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 38.32,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.7,
#   'Country': 'IS',
#   'Description': 'overcast clouds'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 77.09,
#   'Humidity': 1,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'GF',
#   'Description': 'overcast clouds'},
#  {'City': 'Kharan',
#   'Lat': 28.5833,
#   'Lng': 65.4167,
#   'Max Temp': 105.15,
#   'Humidity': 6,
#   'Cloudiness': 0,
#   'Wind Speed': 8.97,
#   'Country': 'PK',
#   'Description': 'clear sky'},
#  {'City': 'Ust-Kulom',
#   'Lat': 61.6864,
#   'Lng': 53.6902,
#   'Max Temp': 35.62,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.48,
#   'Country': 'RU',
#   'Description': 'light rain'},
#  {'City': 'Akureyri',
#   'Lat': 65.6835,
#   'Lng': -18.0878,
#   'Max Temp': 39.13,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'IS',
#   'Description': 'overcast clouds'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 34.65,
#   'Humidity': 61,
#   'Cloudiness': 16,
#   'Wind Speed': 11.36,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'Kalino',
#   'Lat': 58.2504,
#   'Lng': 57.6085,
#   'Max Temp': 40.48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Country': 'RU',
#   'Description': 'light rain'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 88.23,
#   'Humidity': 20,
#   'Cloudiness': 48,
#   'Wind Speed': 7.4,
#   'Country': 'MA',
#   'Description': 'scattered clouds'},
#  {'City': 'Kerman',
#   'Lat': 30.2832,
#   'Lng': 57.0788,
#   'Max Temp': 84.06,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'IR',
#   'Description': 'dust'},
#  {'City': 'Ayagoz',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 80.51,
#   'Humidity': 30,
#   'Cloudiness': 96,
#   'Wind Speed': 14.43,
#   'Country': 'KZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Sarakhs',
#   'Lat': 36.5449,
#   'Lng': 61.1577,
#   'Max Temp': 77.14,
#   'Humidity': 36,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'IR',
#   'Description': 'scattered clouds'},
#  {'City': 'Burgos',
#   'Lat': 42.3394,
#   'Lng': -3.7079,
#   'Max Temp': 82.81,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ES',
#   'Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 76.73,
#   'Humidity': 47,
#   'Cloudiness': 10,
#   'Wind Speed': 5.61,
#   'Country': 'AO',
#   'Description': 'clear sky'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 65.64,
#   'Humidity': 84,
#   'Cloudiness': 10,
#   'Wind Speed': 1.48,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Sainte-Anne-Des-Monts',
#   'Lat': 49.124,
#   'Lng': -66.4924,
#   'Max Temp': 44.47,
#   'Humidity': 93,
#   'Cloudiness': 35,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Description': 'scattered clouds'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 65.01,
#   'Humidity': 50,
#   'Cloudiness': 21,
#   'Wind Speed': 4.88,
#   'Country': 'ZA',
#   'Description': 'few clouds'},
#  {'City': 'Lucera',
#   'Lat': 41.5082,
#   'Lng': 15.3351,
#   'Max Temp': 84.29,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IT',
#   'Description': 'clear sky'},
#  {'City': 'Belomorsk',
#   'Lat': 64.5232,
#   'Lng': 34.7668,
#   'Max Temp': 40.48,
#   'Humidity': 50,
#   'Cloudiness': 17,
#   'Wind Speed': 9.46,
#   'Country': 'RU',
#   'Description': 'few clouds'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 82.35,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'PH',
#   'Description': 'light intensity shower rain'},
#  {'City': 'Adre',
#   'Lat': 13.4667,
#   'Lng': 22.2,
#   'Max Temp': 96.66,
#   'Humidity': 10,
#   'Cloudiness': 69,
#   'Wind Speed': 15.86,
#   'Country': 'TD',
#   'Description': 'broken clouds'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 85.48,
#   'Humidity': 21,
#   'Cloudiness': 84,
#   'Wind Speed': 18.48,
#   'Country': 'SY',
#   'Description': 'broken clouds'},
#  {'City': 'Bedford',
#   'Lat': 52.1346,
#   'Lng': -0.4663,
#   'Max Temp': 69.24,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'GB',
#   'Description': 'clear sky'},
#  {'City': 'Qeshm',
#   'Lat': 26.9581,
#   'Lng': 56.2719,
#   'Max Temp': 96.67,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'IR',
#   'Description': 'clear sky'},
#  {'City': 'Nizhnevartovsk',
#   'Lat': 60.9344,
#   'Lng': 76.5531,
#   'Max Temp': 73.42,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 20.13,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 80.26,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Description': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 80.22,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Description': 'broken clouds'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 45.55,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77.79,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Country': 'LR',
#   'Description': 'light rain'},
#  {'City': 'Prainha',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 71.02,
#   'Humidity': 98,
#   'Cloudiness': 52,
#   'Wind Speed': 2.39,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 61.79,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 77.97,
#   'Humidity': 77,
#   'Cloudiness': 80,
#   'Wind Speed': 8.84,
#   'Country': 'GW',
#   'Description': 'broken clouds'},
#  {'City': 'George Town',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 87.73,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'MY',
#   'Description': 'few clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 85.89,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 78.8,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Country': 'GH',
#   'Description': 'overcast clouds'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 45.12,
#   'Humidity': 98,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'CA',
#   'Description': 'broken clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 52.79,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'IS',
#   'Description': 'clear sky'},
#  {'City': 'Gao',
#   'Lat': 16.6362,
#   'Lng': 1.637,
#   'Max Temp': 95.76,
#   'Humidity': 23,
#   'Cloudiness': 73,
#   'Wind Speed': 13.56,
#   'Country': 'ML',
#   'Description': 'broken clouds'},
#  {'City': 'Dzilam Gonzalez',
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 79,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 7.14,
#   'Country': 'MX',
#   'Description': 'broken clouds'},
#  {'City': 'Kaputa',
#   'Lat': -8.4689,
#   'Lng': 29.6619,
#   'Max Temp': 77.02,
#   'Humidity': 61,
#   'Cloudiness': 89,
#   'Wind Speed': 4.92,
#   'Country': 'ZM',
#   'Description': 'light rain'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 47.34,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Country': 'CL',
#   'Description': 'light rain'},
#  {'City': 'Ponta Do Sol',
# ...
#   'Description': 'clear sky'},
#  {'City': 'Jadu',
#   'Lat': 31.953,
#   'Lng': 12.0261,
#   'Max Temp': 81.23,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 7.11,
#   'Country': 'LY',
#   'Description': 'clear sky'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 83.95,
#   'Humidity': 78,
#   'Cloudiness': 67,
#   'Wind Speed': 16.17,
#   'Country': 'MV',
#   'Description': 'broken clouds'},
#  {'City': 'Nyandoma',
#   'Lat': 61.669,
#   'Lng': 40.1991,
#   'Max Temp': 42.22,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Mosetse',
#   'Lat': -20.75,
#   'Lng': 26.65,
#   'Max Temp': 63.37,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 13.04,
#   'Country': 'BW',
#   'Description': 'clear sky'},
#  {'City': 'Cabo Rojo',
#   'Lat': 18.0866,
#   'Lng': -67.1457,
#   'Max Temp': 76.96,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 6.02,
#   'Country': 'PR',
#   'Description': 'overcast clouds'},
#  {'City': 'Manadhoo',
#   'Lat': 5.7667,
#   'Lng': 73.3833,
#   'Max Temp': 83.62,
#   'Humidity': 77,
#   'Cloudiness': 49,
#   'Wind Speed': 16.51,
#   'Country': 'MV',
#   'Description': 'scattered clouds'},
#  {'City': 'Sayyan',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 79.2,
#   'Humidity': 8,
#   'Cloudiness': 75,
#   'Wind Speed': 17.67,
#   'Country': 'YE',
#   'Description': 'broken clouds'},
#  {'City': 'Santander',
#   'Lat': 43.4647,
#   'Lng': -3.8044,
#   'Max Temp': 87.3,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'ES',
#   'Description': 'clear sky'},
#  {'City': 'Juba',
#   'Lat': 4.8517,
#   'Lng': 31.5825,
#   'Max Temp': 97.03,
#   'Humidity': 34,
#   'Cloudiness': 56,
#   'Wind Speed': 1.54,
#   'Country': 'SS',
#   'Description': 'broken clouds'},
#  {'City': 'Concepcion Del Uruguay',
#   'Lat': -32.4825,
#   'Lng': -58.2372,
#   'Max Temp': 45.99,
#   'Humidity': 99,
#   'Cloudiness': 0,
#   'Wind Speed': 5.23,
#   'Country': 'AR',
#   'Description': 'clear sky'},
#  {'City': 'Kinkala',
#   'Lat': -4.3614,
#   'Lng': 14.7644,
#   'Max Temp': 83.62,
#   'Humidity': 60,
#   'Cloudiness': 63,
#   'Wind Speed': 5.64,
#   'Country': 'CG',
#   'Description': 'broken clouds'},
#  {'City': 'Stolin',
#   'Lat': 51.8912,
#   'Lng': 26.846,
#   'Max Temp': 48.9,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 14.52,
#   'Country': 'BY',
#   'Description': 'light rain'},
#  {'City': 'Tromso',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp': 53.62,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'NO',
#   'Description': 'broken clouds'},
#  {'City': 'Chapleau',
#   'Lat': 47.8405,
#   'Lng': -83.4034,
#   'Max Temp': 39.29,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Description': 'overcast clouds'},
#  {'City': 'Tchibanga',
#   'Lat': -2.85,
#   'Lng': 11.0333,
#   'Max Temp': 83.95,
#   'Humidity': 61,
#   'Cloudiness': 63,
#   'Wind Speed': 3.22,
#   'Country': 'GA',
#   'Description': 'broken clouds'},
#  {'City': 'Vytegra',
#   'Lat': 61.0064,
#   'Lng': 36.4481,
#   'Max Temp': 43.36,
#   'Humidity': 48,
#   'Cloudiness': 6,
#   'Wind Speed': 12.37,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Oxford',
#   'Lat': 51.7522,
#   'Lng': -1.256,
#   'Max Temp': 68.36,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'GB',
#   'Description': 'few clouds'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 43.05,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 20.76,
#   'Country': 'GL',
#   'Description': 'overcast clouds'},
#  {'City': 'Miranda',
#   'Lat': 3.2499,
#   'Lng': -76.2281,
#   'Max Temp': 66.33,
#   'Humidity': 84,
#   'Cloudiness': 81,
#   'Wind Speed': 3.78,
#   'Country': 'CO',
#   'Description': 'broken clouds'},
#  {'City': 'Sumter',
#   'Lat': 28.7086,
#   'Lng': -82.0831,
#   'Max Temp': 75.15,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Kismayo',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 85.46,
#   'Humidity': 66,
#   'Cloudiness': 60,
#   'Wind Speed': 16.13,
#   'Country': 'SO',
#   'Description': 'broken clouds'},
#  {'City': 'Hindoria',
#   'Lat': 23.9,
#   'Lng': 79.5667,
#   'Max Temp': 106.21,
#   'Humidity': 10,
#   'Cloudiness': 25,
#   'Wind Speed': 18.39,
#   'Country': 'IN',
#   'Description': 'scattered clouds'},
#  {'City': 'Vesele',
#   'Lat': 47.0148,
#   'Lng': 34.915,
#   'Max Temp': 69.19,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 15.9,
#   'Country': 'UA',
#   'Description': 'overcast clouds'},
#  {'City': 'Novyy Urengoy',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': 51.33,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 13.53,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Kuopio',
#   'Lat': 62.8924,
#   'Lng': 27.677,
#   'Max Temp': 55.35,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'FI',
#   'Description': 'clear sky'},
#  {'City': 'Zorritos',
#   'Lat': -3.6805,
#   'Lng': -80.6782,
#   'Max Temp': 71.55,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 1.74,
#   'Country': 'PE',
#   'Description': 'clear sky'},
#  {'City': 'San Carlos',
#   'Lat': 9.6612,
#   'Lng': -68.5827,
#   'Max Temp': 76.03,
#   'Humidity': 72,
#   'Cloudiness': 72,
#   'Wind Speed': 0.47,
#   'Country': 'VE',
#   'Description': 'broken clouds'},
#  {'City': 'Piripiri',
#   'Lat': -4.2733,
#   'Lng': -41.7769,
#   'Max Temp': 75.81,
#   'Humidity': 84,
#   'Cloudiness': 50,
#   'Wind Speed': 2.44,
#   'Country': 'BR',
#   'Description': 'scattered clouds'},
#  {'City': 'Hvide Sande',
#   'Lat': 56.0045,
#   'Lng': 8.1294,
#   'Max Temp': 61.09,
#   'Humidity': 80,
#   'Cloudiness': 13,
#   'Wind Speed': 9.19,
#   'Country': 'DK',
#   'Description': 'few clouds'},
#  {'City': 'General Pico',
#   'Lat': -35.6566,
#   'Lng': -63.7568,
#   'Max Temp': 45.52,
#   'Humidity': 50,
#   'Cloudiness': 92,
#   'Wind Speed': 8.43,
#   'Country': 'AR',
#   'Description': 'overcast clouds'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 81.39,
#   'Humidity': 17,
#   'Cloudiness': 100,
#   'Wind Speed': 8.66,
#   'Country': 'CN',
#   'Description': 'overcast clouds'},
#  {'City': 'Hovin',
#   'Lat': 63.1055,
#   'Lng': 10.225,
#   'Max Temp': 54.25,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'NO',
#   'Description': 'overcast clouds'},
#  {'City': 'Rokytne',
#   'Lat': 51.2796,
#   'Lng': 27.214,
#   'Max Temp': 50.14,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.65,
#   'Country': 'UA',
#   'Description': 'overcast clouds'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 89.85,
#   'Humidity': 13,
#   'Cloudiness': 9,
#   'Wind Speed': 9.51,
#   'Country': 'SD',
#   'Description': 'clear sky'},
#  {'City': 'Varangaon',
#   'Lat': 21.0167,
#   'Lng': 75.9,
#   'Max Temp': 102.96,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 20.85,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Belyy',
#   'Lat': 55.8402,
#   'Lng': 32.9419,
#   'Max Temp': 54.63,
#   'Humidity': 37,
#   'Cloudiness': 3,
#   'Wind Speed': 10.25,
#   'Country': 'RU',
#   'Description': 'clear sky'},
#  {'City': 'Idukki',
#   'Lat': 9.85,
#   'Lng': 76.9667,
#   'Max Temp': 72.54,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 5.32,
#   'Country': 'IN',
#   'Description': 'overcast clouds'},
#  {'City': 'Svetlopolyansk',
#   'Lat': 59.4184,
#   'Lng': 52.3605,
#   'Max Temp': 38.12,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Description': 'light rain'},
#  {'City': 'Sherbakul',
#   'Lat': 54.6316,
#   'Lng': 72.3963,
#   'Max Temp': 53.49,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 74.3,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Country': 'GH',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Barreirinhas',
#   'Lat': -2.7469,
#   'Lng': -42.8264,
#   'Max Temp': 77.77,
#   'Humidity': 85,
#   'Cloudiness': 59,
#   'Wind Speed': 2.8,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Baft',
#   'Lat': 29.234,
#   'Lng': 56.6057,
#   'Max Temp': 85.17,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 18.3,
#   'Country': 'IR',
#   'Description': 'clear sky'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 63.77,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.91,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Paulo Afonso',
#   'Lat': -9.4061,
#   'Lng': -38.2147,
#   'Max Temp': 75.9,
#   'Humidity': 67,
#   'Cloudiness': 79,
#   'Wind Speed': 12.12,
#   'Country': 'BR',
#   'Description': 'broken clouds'},
#  {'City': 'Mahbubabad',
#   'Lat': 17.6167,
#   'Lng': 80.0167,
#   'Max Temp': 106.34,
#   'Humidity': 12,
#   'Cloudiness': 45,
#   'Wind Speed': 12.03,
#   'Country': 'IN',
#   'Description': 'scattered clouds'},
#  {'City': 'Deogarh',
#   'Lat': 21.5333,
#   'Lng': 84.7333,
#   'Max Temp': 101.66,
#   'Humidity': 21,
#   'Cloudiness': 60,
#   'Wind Speed': 2.42,
#   'Country': 'IN',
#   'Description': 'broken clouds'},
#  {'City': 'Saurimo',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 80.92,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AO',
#   'Description': 'clear sky'},
#  {'City': 'Conceicao Do Araguaia',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 71.38,
#   'Humidity': 66,
#   'Cloudiness': 48,
#   'Wind Speed': 3.42,
#   'Country': 'BR',
#   'Description': 'scattered clouds'},
#  {'City': 'Pokaran',
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp': 111.36,
#   'Humidity': 4,
#   'Cloudiness': 0,
#   'Wind Speed': 15.73,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Robertsport',
#   'Lat': 6.7533,
#   'Lng': -11.3686,
#   'Max Temp': 76.95,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Country': 'LR',
#   'Description': 'overcast clouds'},
#  {'City': 'Marand',
#   'Lat': 38.4329,
#   'Lng': 45.7749,
#   'Max Temp': 75.36,
#   'Humidity': 19,
#   'Cloudiness': 53,
#   'Wind Speed': 2.48,
#   'Country': 'IR',
#   'Description': 'broken clouds'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 36.34,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 43.02,
#   'Country': 'GL',
#   'Description': 'light rain'},
#  {'City': 'Moa',
#   'Lat': 20.6569,
#   'Lng': -74.9403,
#   'Max Temp': 77.9,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.81,
#   'Country': 'CU',
#   'Description': 'overcast clouds'},
#  {'City': 'Aksarka',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': 36.3,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 20.56,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Cacapava Do Sul',
#   'Lat': -30.5122,
#   'Lng': -53.4914,
#   'Max Temp': 46.8,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'BR',
#   'Description': 'overcast clouds'},
#  {'City': 'Abong Mbang',
#   'Lat': 3.9833,
#   'Lng': 13.1833,
#   'Max Temp': 91.69,
#   'Humidity': 39,
#   'Cloudiness': 81,
#   'Wind Speed': 0.92,
#   'Country': 'CM',
#   'Description': 'broken clouds'},
#  {'City': 'Kanniyakumari',
#   'Lat': 8.0833,
#   'Lng': 77.5667,
#   'Max Temp': 84.27,
#   'Humidity': 73,
#   'Cloudiness': 57,
#   'Wind Speed': 24.32,
#   'Country': 'IN',
#   'Description': 'broken clouds'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 72.75,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Description': 'clear sky'},
#  {'City': 'Sangre Grande',
#   'Lat': 10.5835,
#   'Lng': -61.1177,
#   'Max Temp': 77.05,
#   'Humidity': 74,
#   'Cloudiness': 61,
#   'Wind Speed': 8.19,
#   'Country': 'TT',
#   'Description': 'broken clouds'},
#  {'City': 'Igrim',
#   'Lat': 63.1906,
#   'Lng': 64.4162,
#   'Max Temp': 49.26,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.64,
#   'Country': 'RU',
#   'Description': 'light rain'},
#  {'City': 'Pampas',
#   'Lat': -12.4,
#   'Lng': -74.9,
#   'Max Temp': 47.41,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'PE',
#   'Description': 'overcast clouds'},
#  {'City': 'Demidov',
#   'Lat': 55.2706,
#   'Lng': 31.515,
#   'Max Temp': 57.56,
#   'Humidity': 41,
#   'Cloudiness': 25,
#   'Wind Speed': 11.77,
#   'Country': 'RU',
#   'Description': 'scattered clouds'},
#  {'City': 'Nokaneng',
#   'Lat': -19.6667,
#   'Lng': 22.2667,
#   'Max Temp': 69.39,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 8.72,
#   'Country': 'BW',
#   'Description': 'clear sky'},
#  {'City': 'Bagli',
#   'Lat': 22.65,
#   'Lng': 76.35,
#   'Max Temp': 101.03,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 17.67,
#   'Country': 'IN',
#   'Description': 'clear sky'},
#  {'City': 'Jardim',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 53.33,
#   'Humidity': 69,
#   'Cloudiness': 6,
#   'Wind Speed': 3.38,
#   'Country': 'BR',
#   'Description': 'clear sky'},
#  {'City': 'Manjacaze',
#   'Lat': -24.7117,
#   'Lng': 33.8828,
#   'Max Temp': 66.52,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Country': 'MZ',
#   'Description': 'light rain'},
#  {'City': 'Waldoboro',
#   'Lat': 44.0954,
#   'Lng': -69.3756,
#   'Max Temp': 62.31,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'US',
#   'Description': 'overcast clouds'},
#  {'City': 'Altamira',
#   'Lat': -3.2033,
#   'Lng': -52.2064,
#   'Max Temp': 73.49,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'BR',
#   'Description': 'fog'},
#  {'City': 'Sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 76.6,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.52,
#   'Country': 'MG',
#   'Description': 'overcast clouds'},
#  {'City': 'Dedza',
#   'Lat': -14.3779,
#   'Lng': 34.3332,
#   'Max Temp': 73.89,
#   'Humidity': 46,
#   'Cloudiness': 65,
#   'Wind Speed': 6.26,
#   'Country': 'MW',
#   'Description': 'broken clouds'},
#  {'City': 'Vigrestad',
#   'Lat': 58.5667,
#   'Lng': 5.7,
#   'Max Temp': 60.82,
#   'Humidity': 79,
#   'Cloudiness': 22,
#   'Wind Speed': 7.81,
#   'Country': 'NO',
#   'Description': 'few clouds'},
#  {'City': 'Chabahar',
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp': 90.27,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 13.85,
#   'Country': 'IR',
#   'Description': 'clear sky'},
#  {'City': 'Buchanan',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 76.59,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'LR',
#   'Description': 'moderate rain'},
#  {'City': 'Lipari',
#   'Lat': 38.4674,
#   'Lng': 14.954,
#   'Max Temp': 75.99,
#   'Humidity': 55,
#   'Cloudiness': 2,
#   'Wind Speed': 3.22,
#   'Country': 'IT',
#   'Description': 'clear sky'},
#  {'City': 'Karatau',
#   'Lat': 43.1667,
#   'Lng': 70.4667,
#   'Max Temp': 63.19,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'KZ',
#   'Description': 'overcast clouds'},
#  {'City': 'Shagamu',
#   'Lat': 6.8432,
#   'Lng': 3.6478,
#   'Max Temp': 83.98,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 5.21,
#   'Country': 'NG',
#   'Description': 'light rain'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 86.95,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 13.42,
#   'Country': 'CN',
#   'Description': 'clear sky'},
#  {'City': 'Yenagoa',
#   'Lat': 4.9247,
#   'Lng': 6.2642,
#   'Max Temp': 84,
#   'Humidity': 71,
#   'Cloudiness': 86,
#   'Wind Speed': 4.79,
#   'Country': 'NG',
#   'Description': 'moderate rain'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 100.04,
#   'Humidity': 18,
#   'Cloudiness': 5,
#   'Wind Speed': 10.96,
#   'Country': 'ML',
#   'Description': 'clear sky'},
#  {'City': 'Berdyaush',
#   'Lat': 55.1619,
#   'Lng': 59.1464,
#   'Max Temp': 38.35,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.68,
#   'Country': 'RU',
#   'Description': 'overcast clouds'},
#  {'City': 'Llaillay',
#   'Lat': -32.85,
#   'Lng': -70.9667,
#   'Max Temp': 57.25,
#   'Humidity': 55,
#   'Cloudiness': 90,
#   'Wind Speed': 1.74,
#   'Country': 'CL',
#   'Description': 'overcast clouds'},
#  {'City': 'Itacoatiara',
#   'Lat': -3.1431,
#   'Lng': -58.4442,
#   'Max Temp': 73.08,
#   'Humidity': 89,
#   'Cloudiness': 27,
#   'Wind Speed': 1.05,
#   'Country': 'BR',
#   'Description': 'scattered clouds'},
#  {'City': 'Nassau',
#   'Lat': 40.7507,
#   'Lng': -73.5829,
#   'Max Temp': 75.25,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Description': 'clear sky'}]

# %%
import pandas as pd
cityDF = pd.DataFrame(cityData)
newColumnOrder = ["City", "Country", "Description", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed"]
cityDF = cityDF[newColumnOrder]
outputDataFile = "WeatherPy_Database.csv"
cityDF.to_csv(outputDataFile, index_label="City_ID")
