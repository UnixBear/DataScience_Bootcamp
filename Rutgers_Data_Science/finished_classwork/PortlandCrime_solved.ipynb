# %%
# Import Dependencies
import pandas as pd
import os

# %%
# Reference the file where the CSV is located
crime_file = os.path.join('Resources','crime_incident_data2017.csv')
# Import the data into a Pandas DataFrame
crimeDF = pd.read_csv(crime_file)

# %%
# look for missing values
crimeDF[crimeDF.isnull().any(axis=1)]
# Out:
#                                Address  Case Number Crime Against  \
# 0                                  NaN  17-X4762181        Person
# 1                                  NaN  17-X4757824      Property
# 3                                  NaN  17-X4748982      Property
# 4                                  NaN  17-X4748982      Property
# 13                     UNKNOWN ADDRESS     17-23112      Property
# ...                                ...          ...           ...
# 40974                              NaN  17-X4919770      Property
# 40976  10200 BLOCK OF NE CASCADES PKWY    17-286536      Property
# 40977                              NaN  17-X4921242      Property
# 40991   9300 BLOCK OF NE CASCADES PKWY    17-285508      Property
# 41030                  UNKNOWN ADDRESS    17-286445       Society
#
#             Neighborhood  Number of Records Occur Date Occur Month Year  \
# 0                    NaN                  1     1/1/96           1/1/96
# ...

# %%
# drop null rows
crimeDF.dropna(inplace=True)

# %%
# verify counts
crimeDF.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
crimeDF["Offense Type"].unique()
crimeDF["Offense Type"] = crimeDF["Offense Type"].str.replace("Pocket-Picking","Pick-Pocketing")

# %%
# Combine similar offenses
crimeDF["Offense Type"].unique()
# Out:
# array(['False Pretenses/Swindle/Confidence Game', 'Identity Theft',
#        'Credit Card/ATM Fraud', 'Embezzlement', 'Shoplifting',
#        'All Other Larceny', 'Theft From Motor Vehicle',
#        'Motor Vehicle Theft', 'Burglary',
#        'Theft of Motor Vehicle Parts or Accessories',
#        'Counterfeiting/Forgery', 'Vandalism', 'Theft From Building',
#        'Robbery', 'Aggravated Assault',
#        'Theft From Coin-Operated Machine or Device', 'Intimidation',
#        'Simple Assault', 'Hacking/Computer Invasion',
#        'Drug/Narcotic Violations', 'Pick-Pocketing',
#        'Stolen Property Offenses', 'Weapons Law Violations',
#        'Purse-Snatching', 'Arson', 'Extortion/Blackmail', 'Prostitution',
#        'Kidnapping/Abduction', 'Drug Equipment Violations',
#        'Pornography/Obscene Material', 'Wire Fraud', 'Impersonation',
#        'Assisting or Promoting Prostitution', 'Commercial Sex Acts',
#        'Animal Cruelty', 'Welfare Fraud'], dtype=object)

# %%
# Check to see if you comnbined similar offenses correctly in "Offense Type".
